# %%
import numpy as np 
import matplotlib.pyplot as plt 
x = np.linspace(-2*np.pi, 2*np.pi, 1000)
y = np.sin(x)
z= np.cos(x)
xnum = np.arange(-2*np.pi, 3*np.pi, np.pi)
ynum = np.arange(-1, 2, 0.5)
ax.xaxis.set_label_coords(0.5, -0.1)
plt.plot(x, y, label=r'$\sin(\theta)$', color='r')
plt.plot(x, z, label=r'$\cos(\theta)$', color='g')
plt.xlabel(r'$\theta$')
plt.xticks(xnum, [r'$-2\pi$', r'$-\pi$', r'0', r'$\pi$', r'$2\pi$'])
plt.yticks(ynum)
plt.axes().spines["bottom"].set_position(('data', 0))
plt.axes().spines["left"].set_position(('data', 0))
plt.axhline(y=plt.ylim()[0], color='k')
plt.axvline(x=-2*np.pi, color='k')
plt.axis([-2*np.pi, 2*np.pi, -1.1, 1.1])
plt.legend()
plt.grid()
plt.show()
